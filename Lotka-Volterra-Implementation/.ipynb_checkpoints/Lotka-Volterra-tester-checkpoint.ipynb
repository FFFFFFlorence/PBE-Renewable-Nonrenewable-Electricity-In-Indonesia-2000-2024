# %%
# !pip install numpy pandas scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python314\site-packages (2.3.4)
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python314\site-packages (2.3.3)
# Requirement already satisfied: scipy in c:\users\user\appdata\roaming\python\python314\site-packages (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python314\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import sys
# !{sys.executable} -m pip install scipy matplotlib
# Out:
# Requirement already satisfied: scipy in c:\users\user\env\lib\site-packages (1.16.3)
# Requirement already satisfied: matplotlib in c:\users\user\env\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\user\env\lib\site-packages (from scipy) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\env\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\env\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\env\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\env\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\env\lib\site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
renew = pd.read_csv(
    r"C:\Florence\Campus stuff\Semester 5\Pemodelan Bidang Energi - PBE\TUBES - 11\Data Storage\Final Data\renewable-electricity-Indonesia_2000_2024.csv"
)

nonrenew = pd.read_csv(
    r"C:\Florence\Campus stuff\Semester 5\Pemodelan Bidang Energi - PBE\TUBES - 11\Data Storage\Final Data\non-renewable-electricity-Indonesia_2000_2024.csv"
)

# %%
# Ambil semua kolom yang mengandung "TWh"
renew_cols = [c for c in renew.columns if "TWh" in c]
nonrenew_cols = [c for c in nonrenew.columns if "TWh" in c]

# Total listrik
renew["Renewable_TWh"] = renew[renew_cols].sum(axis=1)
nonrenew["NonRenewable_TWh"] = nonrenew[nonrenew_cols].sum(axis=1)

# %%
df = pd.merge(
    renew[["Year", "Renewable_TWh"]],
    nonrenew[["Year", "NonRenewable_TWh"]],
    on="Year"
)

df["Total"] = df["Renewable_TWh"] + df["NonRenewable_TWh"]
df["s_R"] = df["Renewable_TWh"] / df["Total"]
df["s_N"] = df["NonRenewable_TWh"] / df["Total"]

# %%
print(df.head())
print("\nCheck s_R + s_N ≈ 1:")
print((df["s_R"] + df["s_N"]).head())
# Out:
#    Year  Renewable_TWh  NonRenewable_TWh       Total       s_R       s_N
# 0  2000      10.020525            156.88  166.900525  0.060039  0.939961
# 1  2001      11.650785            167.94  179.590785  0.064874  0.935126
# 2  2002       9.930785            184.08  194.010785  0.051187  0.948813
# 3  2003       9.100805            195.14  204.240805  0.044559  0.955441
# 4  2004       9.670820            207.62  217.290820  0.044506  0.955494
#
# Check s_R + s_N ≈ 1:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# dtype: float64

# %%
plt.figure(figsize=(7,4))
plt.plot(df["Year"], df["s_R"], label="Renewable", linewidth=2)
plt.plot(df["Year"], df["s_N"], label="Non-renewable", linewidth=2)

plt.xlabel("Year")
plt.ylabel("Energy Share")
plt.title("Renewable vs Non-Renewable Electricity Share (Indonesia)")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(5,5))
plt.plot(df["s_R"], df["s_N"], 'o-', linewidth=2)
plt.xlabel("Renewable share (s_R)")
plt.ylabel("Non-renewable share (s_N)")
plt.title("Phase Portrait of Energy Shares")
plt.tight_layout()
plt.show()
